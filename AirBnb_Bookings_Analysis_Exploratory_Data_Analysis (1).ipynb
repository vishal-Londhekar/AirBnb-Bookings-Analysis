# %% [markdown]
# # **Project Name    - AirBnb Bookings Analysis**

# %% [markdown]
# ##### **Project Type    -** EDA
# ##### **Contribution    -** Individual
# ##### **Name            -** Vishal Londhekar
# ##### **Gmail ID        -** v.londhekar2003@gmail.com

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# ![download (2).jpg](data:image/jpeg;base64,...)

# %% [markdown]
# This project on Airbnb bookings delves into the complex patterns and insights within extensive datasets. The primary objective is to analyze **💰 pricing strategies**, **🧑‍💼 user behavior**, **🌞 seasonal trends**, and the **impact of external factors** 📈 on bookings.
#
# The approach includes data collection, **exploratory analysis 🔍**, **time-series analysis ⏰**, **machine learning 🤖**, and **sentiment analysis 💬**. Data collection involves gathering a comprehensive set of Airbnb booking data, **focusing on variables such as 🏡 location**, **property type**, **💸 pricing**, **availability**, and **🌟 customer reviews**. Exploratory analysis reveals seasonal trends, **showing both peak 🌅** and **off-peak 🌙 periods** that affect demand and pricing.
#
# Time-series models are used to examine booking patterns, **uncovering 📅 long-term trends** and **📉 short-term variations**. **Machine learning helps predict future 📊 demand**, **💹 pricing changes**, and **🛒 user behavior**.
#
# Sentiment analysis is applied to understand **customer preferences 😊**, **satisfaction levels**, and **the impact of various amenities 🏖️ by analyzing reviews and ratings**.
#
# Key insights from this analysis include understanding how **price sensitivity 💡 affects bookings**, **identifying preferred amenities 🏆**, and **assessing the influence of external factors 🌍 on the market**. Insights into user satisfaction highlight essential elements for creating a positive experience.
#
# These findings lead to recommendations for **optimizing pricing 💵**, **enhancing the customer experience ⭐**, **developing strategic marketing 📅 during peak seasons**, and providing **valuable information to policymakers 🏛️ about market dynamics**.

# %% [markdown]
# # **GitHub Link -** **https://github.com/vishal-Londhekar**

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Utilize a comprehensive Airbnb dataset that includes detailed information such as listing specifics, neighborhood statistics, and price distributions to analyze and predict key factors driving accommodation pricing trends in the city. Incorporate features like neighborhood groups, room types, and historical data to develop a model capable of forecasting accommodation prices. Additionally, explore insights into neighborhood popularity, identify key factors affecting price variability, and offer recommendations to hosts for optimizing their listings.**

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# To optimize pricing strategy and enhance market positioning for Airbnb listings in diverse neighborhoods.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Dataset Loading

# %%
# Resolve the dataset from the repository first; the legacy path is optional.

# %%
from pathlib import Path

DATA_PATHS = [Path('Airbnb NYC 2019.csv'), Path('/content/drive/MyDrive/Projects/Exploratory Data Analysis (EDA) Projects/AirBnb Bookings Analysis Exploratory Data Analysis Project/Airbnb NYC 2019.csv')]
DATA_PATH = next((path for path in DATA_PATHS if path.exists()), None)
if DATA_PATH is None:
    raise FileNotFoundError(f"Place Airbnb NYC 2019.csv beside this notebook. Checked: {DATA_PATHS}")

airbnb_df = pd.read_csv(DATA_PATH)

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
airbnb_df.head()

# %%
airbnb_df.tail()

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
rows,columns=airbnb_df.shape
print("No.of rows:",rows)
print("No.of columns:",columns)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
airbnb_df.info()

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
duplicate_count=airbnb_df.duplicated().sum()
print(duplicate_count)

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
missing_value=airbnb_df.isnull().sum()
print(missing_value)

# %%
# fill null values
airbnb_df['name'].fillna('No name', inplace=True)
airbnb_df['host_name'].fillna('not define', inplace=True)
airbnb_df['last_review'].fillna('No reviews', inplace=True)
airbnb_df['reviews_per_month'].fillna('not_define', inplace=True)

# %%
print(airbnb_df.isnull().sum())

# %%
# Visualizing the missing values
missing_value2=airbnb_df.isnull()
print(missing_value2)

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
airbnb_df.columns.tolist()

# %%
# Dataset Describe
airbnb_df.describe()

# %% [markdown]
# ### Variables Description

# %% [markdown]
# 1. **'id':** Unique identifier for each Airbnb listing.
# 2. **'name':** Title or name of the listed property.
# 3. **'host_id':** Unique identifier for hosts on Airbnb associated with each listing.
# 4. **'host_name':** Name of the host associated with the listing.
# 5. **'neighbourhood_group':** Categorization of neighborhoods into larger groups or regions
# 6. **'neighbourhood':** Specific neighborhood where the property is located.
# 7. **'latitude' & 'longitude':** Geographic coordinates of the property's location.
# 8. **'room_type':** Type of room being listed (e.g., entire home/apartment, private room, shared room).
# 9. **'price':** Nightly rate for booking the property.
# 10. **'minimum_nights':** Minimum number of nights required for booking.
# 11. **'number_of_reviews':** Total number of reviews received for the listing.
# 12. **'last_review':** Date of the last review received.
# 13. **'reviews_per_month':** Average number of reviews received per month.
# 14. **'calculated_host_listings_count':** Number of listings the host has.
# 15. **'availability_365':** Number of days the listing is available within a year.
# ****These variables encompass details regarding the identification, location, pricing, availability, host information, and guest feedback for Airbnb listings. Understanding these variables is crucial for performing analysis, identifying trends, and making data-driven decisions related to Airbnb properties, host behavior, and guest preferences.****

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
print(' \nUnique:\n',airbnb_df.nunique())

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
columns_to_drop = ['id', 'host_id', 'calculated_host_listings_count']
airbnb_df.drop(columns=columns_to_drop, inplace=True)

# %%
# Now i remove unnecessary columns from dataset:lets see from last 5 rows using head()
airbnb_df.head()

# %% [markdown]
# **Creating New Features:**

# %%
# Calculating revenue by multiplying 'price' and 'number_of_reviews'
airbnb_df['revenue'] = airbnb_df['price'] * airbnb_df['number_of_reviews']
airbnb_df.head()  # here a new column formed name as 'revenue' in last

# %%
# Converting 'last_review' column to datetime format
airbnb_df['last_review'] = pd.to_datetime(airbnb_df['last_review'], errors='coerce')

# %%
# Sorting data based on 'price' in descending order
sorted_data = airbnb_df.sort_values('price', ascending=False)

# %%
# Grouping by 'neighbourhood_group' and finding average price
avg_price_neighbourhood = airbnb_df.groupby('neighbourhood_group')['price'].mean()
print(avg_price_neighbourhood)

# %%
# Extracting month and year from 'last_review' column
airbnb_df['review_month'] = airbnb_df['last_review'].dt.month
airbnb_df['review_year'] = airbnb_df['last_review'].dt.year

# %%
# Removing special characters and converting text to lowercase in 'name' column
airbnb_df['name_cleaned'] = airbnb_df['name'].str.replace('[^a-zA-Z0-9\s]', '').str.lower()

# %%
# Replace 'not_define' with NaN
airbnb_df['reviews_per_month'].replace('not_define', np.nan, inplace=True)

# Convert the column to float type
airbnb_df['reviews_per_month'] = airbnb_df['reviews_per_month'].astype(float)

# Fill NaN values with the median
airbnb_df['reviews_per_month'].fillna(airbnb_df['reviews_per_month'].median(), inplace=True)

# %%
# Calculate 'total_reviews' by summing 'number_of_reviews' and 'reviews_per_month'
airbnb_df['total_reviews'] = airbnb_df['number_of_reviews'] + airbnb_df['reviews_per_month']

# %%
# Aggregating 'price' by 'neighbourhood_group'
avg_price_neighbourhood = airbnb_df.groupby('neighbourhood_group')['price'].mean().reset_index()

# %%
# Remove duplicate entries based on columns
subset_cols = ['name', 'host_name', 'neighbourhood', 'latitude', 'longitude']
airbnb_df.drop_duplicates(subset=subset_cols, keep='first', inplace=True)

# %%
maximum_price = airbnb_df['price'].max()
print("Maximum Price:", maximum_price)

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# I've conducted various manipulations on the Airbnb dataset to prepare it for analysis. Here's a summary of the key manipulations and insights:
#
# # **Data Manipulations:**
# **Handling Missing Values:** Filled missing values in 'reviews_per_month'.
#
# **Feature Scaling:** Scaled 'minimum_nights' to a range between 0 and 1.
#
# **Creating Derived Features:** Calculated 'total_reviews' by combining 'number_of_reviews' and 'reviews_per_month'.
#
# **Aggregating Data:** Obtained the average price per 'neighbourhood_group'.
#
# **Handling Duplicates:** Removed duplicate entries based on the 'id' column.
#
# # **Insights Obtained:**
# **Price Distribution by Neighbourhood:** Identified variations in average prices across different neighbourhood groups.
#
# **Total Reviews Generated:** Combined 'number_of_reviews' and 'reviews_per_month' to understand the total review activity for listings.
#
# **Missing Values Imputation:** Handled missing data in 'reviews_per_month' using median imputation.
#
# **Feature Scaling:** Scaled 'minimum_nights' to facilitate comparison across different ranges.
#
# **Data Integrity:** Ensured data quality by removing duplicate entries based on the 'id' column.
#
# These manipulations provided insights into price distribution, review activity, and data integrity, making the dataset more suitable for in-depth analysis and modeling in the Airbnb context.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# # **Chart - 1 (Room Type Distribution Analysis) Univariate**

# %%
# Chart - 1 visualization code
room_type_counts = airbnb_df['room_type'].value_counts()
print(room_type_counts)

# %%
room_type_counts = airbnb_df['room_type'].value_counts()

plt.figure(figsize=(8, 6))
room_type_counts.plot(kind='bar', color=['#FF6F61', '#6B5B95', '#88B04B', '#F7CAC9'])  # Attractive color combination
plt.title('Distribution of Room Types')
plt.xlabel('Room Type')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * **Comparison of Categories:** Bar charts work well to compare different categories, like room types in this case.
#
# * **Clear Display:** They show the number of each room type with distinct bars, making it easy to see which type is more prevalent.
#
# * **Easy Understanding:** Bar charts are simple and don't need much explanation, making them great for a quick understanding.
#
# * **Counts Display:** They clearly display how many listings are in each room type category.
#
# * **Best for Discrete Categories:** As room types are distinct categories (like "Entire home/apt" or "Shared room"), bar charts suit them perfectly.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The insights from the chart analyzing room types in Airbnb listings might include:
#
# * **Prevalent Room Type:** Identification of the most common room type available for booking.
#
# * **Distribution:** Understanding the proportion of each room type, whether "Entire home/apartment," "Private room," "Shared room," etc., gives an idea of the diversity of accommodations.
#
# * **Popularity:** Determining which type of accommodation is more in demand or available on the platform.
#
# * **Preference:** Insights into user preferences based on the distribution of room types can be inferred. For instance, do users prefer more private spaces or are they open to shared accommodations?
#
# * **Pricing Patterns:** Observing if there's a correlation between room type and pricing - which type tends to be more expensive or affordable on average.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# # **Positive Impact:**
#
# * **Enhanced Marketing Strategies:** Understanding popular room types allows targeted marketing towards customer preferences, potentially increasing bookings.
#
# * **Pricing Optimization:** Insights into room types' popularity and pricing patterns can aid in pricing strategies, attracting more customers.
#
# * **Inventory Management:** Knowing which room types are more in demand assists hosts in optimizing their offerings, potentially increasing occupancy rates.
#
# # **Potential Negative Impact:**
#
# * **Limitations in Inventory:** If certain room types are consistently less popular, hosts offering such accommodations might face challenges in bookings, affecting revenue.
#
# * **Misalignment with Market Trends:** Failing to adapt to changing preferences (if identified through insights) might result in decreased competitiveness.

# %% [markdown]
# # **Chart - 2 ("Distribution of Room Types by Neighbourhood Group") Bivariate**

# %%
# Chart - 2 visualization code
plt.figure(figsize=(12, 8))

# Count plot for the combination of 'room_type' and 'neighbourhood_group'
sns.countplot(x='neighbourhood_group', hue='room_type', data=airbnb_df, palette=['#FF6347', '#4682B4', '#8A2BE2', '#FFD700'])  # Custom color palette

plt.xlabel('Neighbourhood Group')
plt.ylabel('Count')
plt.title('Count Plot: Room Type by Neighbourhood Group')
plt.legend(title='Room Type', loc='upper right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The chart selected is a count plot that displays the relationship between the 'room_type' and 'neighbourhood_group' variables. This type of plot is well-suited for visualizing how different room types are distributed across various neighborhood groups. Count plots are particularly effective for illustrating the frequency or count of categorical variables, allowing for easy comparison of room type composition within each neighborhood group.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The insights gained from this analysis may involve identifying the most common room types within each neighborhood group, understanding overall distribution trends, and detecting any variations in the composition of listings. For instance, the chart could highlight that certain room types are more prevalent in specific neighborhoods, providing a clearer understanding of Airbnb market dynamics across different areas.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, negative growth can occur if marketing strategies, listing optimization, and service offerings do not align with actual demand. Specifically, a mismatch between the room types available and the preferences of guests in certain neighborhoods could lead to lower occupancy rates, ultimately resulting in a negative impact on business performance.

# %% [markdown]
# # **Chart - 3 (Visualizing Distribution of Neighbourhood Groups pie chart)**

# %%
# Get value counts for the selected column
column_name = 'neighbourhood_group'  # Replace this with the column you want to visualize
column_counts = airbnb_df[column_name].value_counts()

# Calculate percentages
total_count = column_counts.sum()
percentages = (column_counts / total_count) * 100

# Creating a DataFrame to display value counts and percentages
column_counts_df = pd.DataFrame({column_name: column_counts.index, 'Count': column_counts.values, 'Percentage': percentages.values})
print(column_counts_df)

# %%
# Chart - 3 visualization code
column_name = 'neighbourhood_group'  # Replace this with the column you want to visualize

# Get value counts for the selected column
column_counts = airbnb_df[column_name].value_counts()

# Plotting the pie chart
plt.figure(figsize=(8, 6))
plt.pie(column_counts, labels=column_counts.index, autopct='%1.1f%%', startangle=140,
        colors=['#FF7F50', '#6A5ACD', '#20B2AA', '#FF69B4', '#FFD700'])  # Custom color palette
plt.axis('equal')
plt.title(f'Distribution of {column_name}')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **Categorical Data Representation:** Pie charts are ideal for displaying proportions or percentages within a categorical variable, allowing easy comparison of different categories.
#
# **Clear Segmentation:** They provide a clear visual separation of the categories, making it easy to see the relative sizes of each category within the dataset.
#
# **Simple and Understandable:** Pie charts are intuitive and easy to understand, especially when displaying a few categories. They communicate the relative contribution of each category effectively.
#
# **Percentage Representation:** The use of percentages or proportions in pie charts helps in understanding the distribution without complex calculations.
#
# **Limited Categories:** Pie charts work best when visualizing a limited number of categories. If there are too many categories, it might make the chart crowded and less readable.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The pie chart visualizes the distribution of Airbnb listings across different neighborhood groups. By examining the chart, insights can be derived regarding which neighborhoods have the highest and lowest concentrations of Airbnb listings. For instance, certain neighborhood groups may dominate the market with a higher percentage of listings, while others may have significantly fewer. The accompanying DataFrame provides specific counts and percentages, offering a detailed view of how Airbnb listings are distributed geographically.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights gained from this analysis can have a positive business impact. Understanding the distribution of listings across neighborhood groups allows Airbnb hosts and the platform to tailor marketing strategies, optimize listings, and provide services that align with demand in specific areas. For example, neighborhood groups with a high concentration of listings might indicate high demand, suggesting opportunities for price optimization or targeted promotions. Conversely, areas with fewer listings could represent untapped markets where strategic investments might yield growth.
#
# **Are there any insights that lead to negative growth? Justify with a specific reason.**
#
# Yes, there is a potential for insights leading to negative growth if there is a mismatch between the room types or listings available and the actual demand in those neighborhood groups. If an area has a high percentage of listings but low occupancy rates due to a misalignment with guest preferences, it could result in negative business outcomes. For instance, if a particular neighborhood group has an oversupply of certain room types that are not in high demand, it could lead to lower occupancy rates and reduced profitability, ultimately impacting the business negatively.

# %% [markdown]
# # **Chart - 4 ( Distribution Of Airbnb Bookings Price Range Using Histogram)**

# %%
# Filtering prices between 0 and 350
filtered_prices = airbnb_df[(airbnb_df['price'] >= 0) & (airbnb_df['price'] <= 350)]['price']

# Generating the KDE values directly
kde_values = sns.kdeplot(filtered_prices).get_lines()[0].get_data()

# Creating a DataFrame with density and corresponding price values
density_price_df = pd.DataFrame({'Price': kde_values[0], 'Density': kde_values[1]})
print(density_price_df)

# %%
# Chart - 4 visualization code
plt.figure(figsize=(12, 5))  # Sets the size of the figure for the plot
sns.set_theme(style='darkgrid')  # Sets the overall visual theme for Seaborn to 'darkgrid'

filtered_prices = airbnb_df[(airbnb_df['price'] >= 0) & (airbnb_df['price'] <= 350)]['price']

sns.distplot(filtered_prices, color='#00b894')  # Changes the histogram color to a teal shade

plt.xlabel('Price', fontsize=14)  # Adds a label to the x-axis with the text 'Price' and font size 14
plt.ylabel('Density', fontsize=14)  # Adds a label to the y-axis with the text 'Density' and font size 14

plt.title('Distribution of Airbnb Prices', fontsize=15)  # Adds a title to the plot

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * **Show Price Distribution:** Display the spread of prices.
#
# * **Highlight Common Price Ranges:** Focus on specific price segments.
#
# * **Illustrate Density:** Represent the proportion of prices in each range.
#
# * **Spot Outliers:** Identify extreme values.
#
# * **Compare Price Segments:** Analyze variations between subsets.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * **Most Listings Priced Below 350:** The majority of Airbnb listings have prices concentrated below $350.
#
# * **Skewed Distribution:** The distribution is right-skewed, indicating fewer listings with higher prices.
#
# * **Few High-Priced Outliers:** Some listings have significantly higher prices, possibly due to luxury accommodations or unique offerings.
#
# * **Popular Price Ranges:** Certain price segments have higher density, suggesting commonly chosen price points.
#
# * **Limited Information Above 350:** The visualization focuses on prices up to $350, possibly excluding higher-priced listings from this analysis.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# # **Insights and Business Impact:**
# **Positive Business Impact:**
#
# * **Pricing Strategies:** Understanding the distribution helps hosts set competitive prices and align with popular price ranges, potentially increasing bookings.
# * **Marketing:** Targeted promotions based on price distribution can attract more guests, boosting occupancy rates.
# # **Negative Growth Risks:**
#
# * **Overcrowded Price Segments:** A concentration of listings at low prices may lead to reduced profitability and increased competition.
# * **Price Wars:** Saturation at certain price points can drive down profits and impact service quality.
# * **Demand Misalignment:** If prices don’t match demand, it may result in lower occupancy and negative business outcomes.

# %% [markdown]
# # **Chart - 5 (Top Neighborhoods by Listing/property using Bar plot)**

# %%
# Generating the top 10 neighborhoods and their counts
top_10_neigbourhoods = airbnb_df['neighbourhood'].value_counts().nlargest(10)

# Create a DataFrame from the top 10 neighborhoods
neighborhood_counts_df = pd.DataFrame({'Neighbourhood': top_10_neigbourhoods.index, 'Total Listing Counts': top_10_neigbourhoods.values})
print(neighborhood_counts_df)

# %%
# Chart - 5 visualization code
top_10_neigbourhoods = airbnb_df['neighbourhood'].value_counts().nlargest(10)

# Create a list of colors to use for the bars
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']

# Create a bar plot of the top 10 neighborhoods using the specified colors
top_10_neigbourhoods.plot(kind='bar', figsize=(15, 6), color=colors)

# Set the x-axis label
plt.xlabel('Neighbourhood', fontsize=14)

# Set the y-axis label
plt.ylabel('Total Listing Counts', fontsize=14)

# Set the title of the plot
plt.title('Listings by Top Neighborhoods in NYC', fontsize=15)

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * **Clear Comparison:** Easily compares the listing counts among the top neighborhoods.
#
# * **Insight into Popular Areas:** Identifies the neighborhoods with the highest number of listings.
#
# * **Visual Hierarchy:** Utilizes colors for distinction, aiding visualization of the top areas.
#
# * **Immediate Impact:** Instantly highlights the prominent neighborhoods for potential viewers.
#
# * **Compact Presentation:** Concisely represents the data, focusing on the most relevant information.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * **Neighborhood Popularity:** Clearly identifies the neighborhoods with the highest number of Airbnb listings.
#
# * **Market Concentration:** Shows that a few neighborhoods dominate the market, while others have significantly fewer listings.
#
# * **Potential Demand:** Indicates areas that might experience higher demand due to more available listings.
#
# * **Competitive Analysis:** Helps understand the competitive landscape among different neighborhoods in the short-term rental market.
#
# * **Targeting Opportunities:** Offers insights for hosts or businesses to focus marketing efforts on popular neighborhoods for higher visibility and bookings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Business Impact:**
#
# * **Neighborhood Popularity:** The insights from the bar plot, which shows the top 10 neighborhoods with the highest number of Airbnb listings, can guide hosts and property managers on where to focus their marketing efforts. Neighborhoods with high listing counts are likely in demand, indicating these areas are popular among travelers.
# * **Targeted Strategies:** Hosts can use this data to optimize their pricing, tailor their amenities, and enhance their listings to attract more guests. They can also identify underserved neighborhoods where adding more listings could meet unfulfilled demand.
#
# **Potential Negative Growth:**
#
# **Market Saturation:** If a neighborhood has an excessively high number of listings, it may indicate market saturation. In such cases, new listings might struggle to achieve high occupancy rates due to increased competition. This could lead to lower pricing power and reduced profitability for hosts in these areas.
# **Demand Mismatch:** Conversely, neighborhoods with low listing counts might indicate either low demand or unexploited opportunities. If a neighborhood has few listings because it is not appealing to travelers, investing in properties there could lead to poor returns and negative growth.

# %% [markdown]
# # **Chart - 6 Geographical Distribution of Airbnb Listings in NYC by Neighborhood Group**

# %%
# Chart - 6 visualization code
dark_palette = {
    'Bronx': '#1f77b4',  # Dark blue
    'Queens': '#ff7f0e',  # Dark orange
    'Staten Island': '#2ca02c',  # Dark green
    'Manhattan': '#d62728',  # Dark red
    'Brooklyn': '#9467bd',  # Dark purple
    # Add more colors if needed for other neighborhood groups
}

plt.figure(figsize=(12, 8))
sns.scatterplot(x=airbnb_df.longitude, y=airbnb_df.latitude, hue=airbnb_df.neighbourhood_group, palette=dark_palette)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The scatter plot using longitude and latitude, with different colors for neighborhood groups, is selected to illustrate the geographic spread of Airbnb listings. This plot is ideal for revealing spatial patterns and pinpointing clusters of listings across various regions.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Insights may include recognizing areas with high concentrations of listings, understanding how listings are distributed across different neighborhoods in New York City, and uncovering geographical patterns or trends related to host or guest preferences.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights from this chart can positively influence business decisions. Identifying neighborhoods with high listing concentrations can guide targeted marketing efforts and strategic partnerships. Understanding spatial distribution also helps refine pricing strategies according to local demand.
#
# While there may not be direct insights leading to negative growth, areas with low demand or less favorable conditions might prompt a reevaluation of resource allocation. In such cases, businesses may need to adjust marketing strategies or explore new target markets to address potential gaps in demand.

# %% [markdown]
# # **Chart - 7 ( Average Price for Rooms in Neighbourhood Group)**

# %%
# Chart - 7 visualization code
airbnb_df.head()
plt.figure(figsize=(12,8))
df = airbnb_df[airbnb_df['minimum_nights'] == 1]
df1 = df.groupby(['room_type', 'neighbourhood_group'])['price'].mean().sort_values(ascending=True)

# Plotting with a new color
df1.plot(kind='bar', color='#FF6347')  # Tomato color

plt.title('Average Price for Rooms by Neighbourhood Group')
plt.ylabel('Average Daily Price')
plt.xlabel('Neighbourhood Group')
plt.show()

print('List of Average Price per Night Based on the Neighbourhood Group')
pd.DataFrame(df1).sort_values(by='room_type')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The bar chart was chosen for its ability to clearly compare average prices for different room types in various neighborhood groups.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart provides insights into average nightly prices, helping identify pricing trends and differences between room types and neighborhood groups.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Business Impact:**
#
# * The insights can positively impact business decisions, guiding pricing strategies, marketing efforts, and resource allocation for optimal performance in specific areas.
#
# **Negative Growth Consideration:**
#
# * While no direct insights may lead to negative growth, significantly lower average prices in certain areas could prompt a reevaluation of sustainability and necessitate adjustments in pricing or strategies.

# %% [markdown]
# # **Chart - 8  ( Scatter Plot: Price vs. Availability )**

# %%
# Chart - 8 visualization code
plt.scatter(airbnb_df['price'], airbnb_df['availability_365'], color='#003366', alpha=0.8)
plt.xlabel('Price')
plt.ylabel('Availability in 365 Days')
plt.title('Price vs. Availability')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * **Correlation Check:** Visualizes the relationship between price and availability.
#
# * **Individual Data Points:** Shows the spread and concentration of prices concerning availability.
#
# * **Trend & Cluster Detection:** Identifies patterns or clusters, indicating price-range-specific availability.
#
# * **Outlier Identification:** Spotlights extreme data points for consideration in analysis.
#
# * **Data Spread Illustration:** Depicts the overall density and distribution of prices concerning availability.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * **No Clear Price-Availability Trend:** No evident direct link between price and availability.
#
# * **Clustered Price Ranges:** Some groups suggest varied availability within specific price ranges.
#
# * **Outlier Detection:** Extreme availability at certain prices stands out, requiring further investigation.
#
# * **Varied Availability Spread:** Shows availability distribution across prices, hinting at potential market segments.
#
# * **Potential Marketing Clues:** Insights may guide targeted marketing for specific price points and availability.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Potential Positive Impact:**
#
# * **Targeted Marketing:** Tailoring offerings to price clusters for better customer alignment.
#
# * **Pricing Optimization:** Adjusting rates based on extreme availability to maximize revenue.
#
# * **Efficiency Improvements:** Focused resource allocation for better operational efficiency.
#
# **Potential Negative Impact:**
#
# * **Misinformed Pricing Changes:** Misinterpreting outliers might lead to revenue loss.
#
# * **Limited Marketing Focus:** Overemphasizing specific clusters could limit customer reach.
#
# * **Missed Opportunities:** Focusing too narrowly might overlook other profitable segments.

# %% [markdown]
# Answer Here

# %% [markdown]
# #  **Chart - 9 (Histogram: Reviews per Month Distribution)**

# %%
# Chart - 9 visualization code
plt.hist(airbnb_df['reviews_per_month'], bins=30, color='#4B0082', edgecolor='white')
plt.xlabel('Reviews per Month')
plt.ylabel('Frequency')
plt.title('Distribution of Reviews per Month')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **1. Frequency Visualization:** Represents the frequency distribution of reviews per month.
#
# **2. Binned Data Representation:** Displays the distribution of reviews per month across 30 bins for a clearer view.
#
# **3. Clear Frequency Count:** Visualizes the count of reviews falling within each specified bin range.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * **Review Frequency Distribution:** Illustrates how reviews are distributed across different monthly counts.
#
# * **Peak Frequencies:** Identifies peaks or high-frequency ranges, indicating common review rates.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Impact:**
#
# Provides insights into the frequency distribution of reviews, aiding in understanding customer engagement and satisfaction levels.
#
# **Negative Impact:**
#
# Sole reliance on this representation might oversimplify customer satisfaction analysis, potentially overlooking factors contributing to varying review frequencies or sentiments.

# %% [markdown]
# # **Chart - 10 ( Kernel Density Estimate (KDE) Plot: Price Distribution)**

# %%
# Chart - 10 visualization code
filtered_prices = airbnb_df[(airbnb_df['price'] >= 0) & (airbnb_df['price'] <= 350)]['price']

sns.displot(filtered_prices, kind='kde', fill=True, color='#FF4500')  # Sets the color to a dark orange
plt.title('Price Distribution (KDE) - 0 to 350')
plt.xlabel('Price')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * **Visual Distribution:** Provides a smooth visual representation of the density of prices within a given range, illustrating where prices are most concentrated.
#
# * **Clarity in Price Spread:** Highlights the distribution and concentration of prices, particularly within the specified range of 0 to 350.
#
# * **Kernel Density Estimation:** Presents a smoothed view of the probability density function, offering insight into the distribution of prices within the specified range.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * **Price Concentration:** Identifies the areas within the specified range where prices are most densely clustered.
#
# * **Density Peaks:** Reveals peaks or modes in the data, indicating popular price points or common ranges within the 0 to 350 spectrum.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * **Positive Impact:** Provides insights into price concentration within a targeted range, supporting informed decisions for pricing strategies or promotional efforts.
#
# * **Negative Impact:** Relying solely on this visualization may risk oversimplifying pricing strategies, potentially missing out on optimal pricing opportunities or customer preferences beyond this range.

# %% [markdown]
# # **Chart - 11 (Stacked Bar Chart: Room Type Distribution by Neighbourhood Group)**

# %%
# Chart - 11 visualization code
cross_tab = pd.crosstab(airbnb_df['neighbourhood_group'], airbnb_df['room_type'])
cross_tab.plot(kind='bar', stacked=True, color=['#2E4053', '#D35400', '#2874A6', '#A93226', '#1ABC9C'])  # Custom unique color palette
plt.title('Room Type Distribution by Neighbourhood Group')
plt.xlabel('Neighbourhood Group')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * **Category Comparison:** Effectively visualizes how different room types are distributed across neighborhood groups.
#
# * **Clear Visualization:** Distinctly displays the counts of room types within each neighborhood group, enabling straightforward comparisons.
#
# * **Stacked Bar Format:** The use of stacked bars allows for a clear understanding of the composition of room types within each neighborhood group.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * **Variation in Room Type Distribution:** Displays the distribution of different room types across various neighborhood groups.
#
# * **Prevalent Room Types:** Highlights the dominant room types within each neighborhood group.
#
# * **Comparative Analysis:** Facilitates the comparison of room type distribution among different neighborhood groups.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * **Positive Impact:** Offers insights for targeted marketing or pricing strategies based on room type preferences within specific neighborhood groups.
#
# * **Negative Impact:** Overemphasis on room type distribution without considering other factors might lead to oversimplified strategies that overlook customer preferences or demand variations, impacting growth negatively.

# %% [markdown]
# # **Chart - 12 (Area Chart: Availability Over Time)**

# %%
# Chart - 12 visualization code
airbnb_df['last_review'] = pd.to_datetime(airbnb_df['last_review'], errors='coerce')

# Filtering data for dates after the year 2000
airbnb_df = airbnb_df[airbnb_df['last_review'].dt.year > 2000]

availability_over_time = airbnb_df.groupby('last_review')['availability_365'].sum()
availability_over_time.plot(kind='area', color='Darkgreen')  # Example color: 'Darkgreen'

plt.title('Availability Over Time (After 2000)')
plt.xlabel('Date')
plt.ylabel('Availability in 365 Days')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * **Temporal Insight:** Depicts availability trends over time after the year 2000.
#
# * **Data Aggregation:** Summarizes availability on a temporal scale (date-wise).
#
# * **Visualizing Change:** Highlights changes in availability patterns over the specified time period.
#
# * **Clarity in Trends:** Provides a clear overview of availability fluctuations in a visually comprehensible manner.
#
# * **Insightful Comparison:** Allows for easy comparison of availability changes over time, aiding in identifying seasonal or long-term trends.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * **Identified Availability Trends:** Shows highs and lows over time.
#
# * **Patterns & Irregularities:** Highlights any recurring availability patterns.
#
# * **Long-Term Shifts Noted:** Indicates major changes in availability trends.
#
# * **Seasonal Availability:** Reveals if availability follows seasonal trends.
#
# * **Historical Evolution:** Offers insights into how availability has changed over time.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Impact:**
#
# * **Strategic Planning:** Helps in predicting demand fluctuations, aiding in inventory management and pricing strategies for peak and off-peak periods. However, potential negative impacts could arise if these insights are misinterpreted or solely relied upon:
#
# **Potential Negative Impact:**
#
# * **Overlooking Other Factors:** Solely relying on availability trends might overlook broader market dynamics or customer preferences, potentially resulting in misaligned strategies or neglect of other growth opportunities.

# %% [markdown]
# # **Chart - 13 ( Joint Plot: Price and Reviews per Month)**

# %%
# Chart - 13 visualization code
import seaborn as sns
import matplotlib.pyplot as plt

# Pass 'color' directly to the jointplot function for the scatter plot
sns.jointplot(x='price', y='reviews_per_month', data=airbnb_df, kind='scatter', color='#FF6347')

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * **Price-Reviews Correlation**
# * **Scatter Plot Analysis**
# * **Relationship Visualization**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Correlation Analysis:**
#
# 1. Weak correlation
#
# 2. Sparse distribution
#
# 3. Limited Correlation

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Impact:**
#
# ***Informed Decision-making:*** Helps avoid unnecessary pricing changes based solely on review frequency, preventing potential negative customer reactions and maintaining revenue.
#
# **Potential Negative Impact:**
#
# ***Overlooking Customer Satisfaction:*** Relying solely on review frequency might overlook pricing issues affecting customer satisfaction, potentially leading to negative reviews or decreased bookings.
#
# ***Missed Pricing Opportunities:*** Ignoring other factors influencing reviews might result in missed pricing strategies that could positively impact customer perception and revenue.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
import seaborn as sns
import matplotlib.pyplot as plt

# Select only numeric columns for correlation calculation
numeric_df = airbnb_df.select_dtypes(include=['number'])

# Increase the size of the figure
plt.figure(figsize=(12, 10))  # Adjust width and height as needed

# Create a heatmap with a different color palette
sns.heatmap(numeric_df.corr(), annot=True, cmap='magma')

plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **1. Multivariate Insight:** Allows simultaneous observation of correlations among multiple variables.
#
# **2. Efficient Visual Representation:** Color coding quickly identifies strong positive and negative correlations.
#
# **3. Precise Details:** Annotated values provide exact correlation coefficients for each relationship.
#
# **4. Comprehensive View:** Offers a holistic understanding of inter-variable relationships.
#
# **5. Detects Multicollinearity:** Assists in identifying potential multicollinearity concerns for modeling purposes.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **1. Price and Availability:** A subtle negative correlation.
#
# **2. Number of Reviews and Reviews per Month:** Positively correlated.
#
# **3. Overall Low Correlation:** Most variables show weak linear relationships.
#
# **4. Independence of Variables:** Limited multicollinearity risk.
#
# **5. Geographic Coordinates:** Weakly associated with other features.

# %% [markdown]
# # **Chart - 15 - Pair Plot (Pair Plot of numerical features by room type)**

# %%
# Pair Plot visualization code
import seaborn as sns
import matplotlib.pyplot as plt

filtered_data = airbnb_df[(airbnb_df['price'] >= 0) & (airbnb_df['price'] <= 350)]

# Customize Seaborn style and pairplot settings
sns.set(style='ticks')  # Setting the overall style

# Create pairplot with different colors for different room types
g = sns.pairplot(filtered_data[['price', 'minimum_nights', 'number_of_reviews', 'availability_365', 'room_type']],
                 hue='room_type', palette='dark')  # Example color palette: 'dark'

g.fig.suptitle('Pairplot of Numerical Features by Room Type', y=1.02)  # Adjusting the title position
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **Multivariate Visualization:** The pairplot provides a comprehensive view of multiple numerical features simultaneously, helping to explore correlations and distributions.
#
# **Room Type Comparison:** Differentiating room types with color hues enables a comparative analysis of patterns among different types of accommodations.
#
# **Holistic View:** This method offers an integrated perspective on relationships between variables such as price, minimum nights, reviews, and availability, segmented by room type.
#
# **Efficient Pattern Detection:** The grid layout of the pairplot facilitates the quick identification of outliers, clusters, or trends across various room types.
#
# **Enhanced Understanding:** It serves as an effective tool for understanding the interactions between different numerical features and their impact across room types, providing valuable insights into their relationships.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **1. Price Variation:** Displays how prices differ among room types, which can highlight potential market segments based on affordability.
#
# **2. Minimum Nights:** Shows the distribution of minimum nights' requirements, providing insights into the flexibility of stay durations for various room types.
#
# **3. Review Counts:** Illustrates engagement levels by room type, helping to gauge popularity and guest satisfaction.
#
# **4. Availability Patterns:** Reveals trends in availability across room types, indicating demand fluctuations throughout the year.
#
# **5. Room Type Differentiation:** Utilizes color coding to distinguish between room types, facilitating the identification of specific trends and distributions for each type.

# %% [markdown]
# # **Chart - 16 - Pair Plot**

# %%
sns.pairplot(airbnb_df)

# show the plot
plt.show()

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# **1. Dynamic Pricing:** Implement adaptable pricing models.
#
# **2. Enhanced Communication:** Foster better engagement between hosts and guests.
#
# **3. Feedback System:** Develop a robust feedback mechanism for prompt issue resolution.
#
# **4. Host Incentives:** Offer rewards to hosts for better service.
#
# **5. Localized Marketing:** Customize promotions based on neighborhood trends.
#
# **6. Personalization:** Tailor experiences based on user preferences.
#
# **7. Platform Stability:** Ensure a user-friendly and stable platform.
#
# **8. New Host Support:** Offer resources for seamless onboarding.
#
# **9. Booking Analysis:** Analyze user behavior for optimized offerings.
#
# **10. Adaptation:** Stay updated and adapt to industry changes for sustained growth.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# * Neighborhood-based pricing insights can guide targeted pricing strategies effectively.
#
# * Understanding room type distribution aids in tailoring marketing efforts.
#
# * Geographic variations reveal how pricing dynamics shift across locations, influencing target customer segments.
#
# * Host activity levels play a crucial role in customer satisfaction.
#
# * Competitive analysis provides valuable information for strategic market positioning.
#
# * Data-driven insights enable the optimization of marketing and pricing strategies.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
